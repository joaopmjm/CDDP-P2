# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 2

# %% [markdown]
# ___
# ## Nome 1 João Pedro Montefeltro Junqueira Meirelles
#
# ## Nome 2 Ester dos Santos Quintino
#
# ___

# %% [markdown]
# ___
#
# ## 1. Problema
#
# O Classificador Naive-Bayes, o qual se baseia no uso do teorema de Bayes, é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser SPAM considerando as palavras em seu conteúdo e, de forma complementar, permite calcular a probabilidade de uma mensagem ser HAM dada as palavras descritas na mensagem.
#
# Para realizar o MVP (minimum viable product) do projeto, você precisa programar uma versão do classificador que "aprende" o que é uma mensagem SPAM considerando uma base de treinamento e comparar o desempenho dos resultados com uma base de testes.

# %% [markdown]
# ___
# ## 2. Separação da base de dados em Treinamento e Teste
#
# A base de dados deve ser separada em duas partes, aleatoriamente, considerando:
#
#     75% dos dados para a parte Treinamento; e
#     25% dos dados para a parte Teste.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as jeca
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Ester Quintino\Desktop\Projeto2CDDP

# %% [markdown]
# # Lendo a base de dados

# %%
dados = pd.read_excel('spamham.xlsx')
dados = dados.iloc[np.random.permutation(len(dados))]

# %%
num = len(dados.Email)
setenta_cinco = int(num*0.75)

# %% [markdown]
# ___
# ## 3. Classificador Naive-Bayes

# %% [markdown]
# # Limpeza das mensagens e remoção dos caracteres que não afetam a classificação

# %%
arranca = [':',',','"','/',';','.','=','+','(',')','*']
for i in range(num):
    dados.Email[i:i+1] = dados.Email[i:i+1].str.replace('  ',' ') # Mudança de 2 espaços para 1
    for j in arranca:
        dados.Email[i:i+1] = dados.Email[i:i+1].str.replace(j,'') 

dados.Email
# Out:
# 2337                             Alright see you in a bit
# 4078               O i played smash bros ltgt religiously
# 2239                       K I'll call you when I'm close
# 1921    I'll be in sch fr 46 I dun haf da book in sch ...
# 4324        Am only searching for good dual sim mobile pa
# 2296                               Draw vai dont think so
# 1439    In fact when do you leave I think addie goes b...
# 3905                       Went fast asleep deartake care
# 68      Did you hear about the new \Divorce Barbie\ It...
# 3945    How u doin baby girl hope u are okay every tim...
# 144                             Yes see ya not on the dot
# 497     Some of them told accenture is not confirm Is ...
# 4165    Well if I'm that desperate I'll just call arma...
# 5039    Natalie 20F is inviting you to be her friend R...
# 4885                               Or just do that 6times
# 1562    Dude just saw a parked car with its sunroof po...
# 3159                      How much did ur hdd casing cost
# 1524                           Hicts employee how are you
# 3032                           Aight lemme know what's up
# 2724          No But we'll do medical missions to nigeria
# 2209    Just wanted to say holy shit you guys weren't ...
# 4621                 They finally came to fix the ceiling
# 5281                   And how you will do that princess
# 2668    we tried to contact you re your response to ou...
# 4889    Sounds like there could be a lot of time spent...
# 3539    I'll get there at 3 unless you guys want me to...
# 5195    Darren was saying dat if u meeting da ge den w...
# 88             I'm really not up to it still tonight babe
# 4171                                Sorry I'll call later
# 4986    No rushing I'm not working I'm in school so if...
#                               ...
# 2039          You always make things bigger than they are
# 2113    Sunshine Hols To claim ur med holiday send a s...
# 697     meet you in corporation st outside gap ‰Û you ...
# 4856    Thanks and Or bomb and date as my phone wanted...
# 5136    There are some nice pubs near here or there is...
# 1206    As a SIM subscriber you are selected to receiv...
# 2600                                                 Okie
# 1181                            You flippin your shit yet
# 3835                      Then Ì come n pick me at 530 ar
# 5495    Good afternoon my love How goes your day How d...
# 5131    That sucks I'll go over so u can do my hair Yo...
# 1667                              Yesbut they said its IT
# 3866            Alright we're hooked up where you guys at
# 590     For ur chance to win a å£250 wkly shopping spr...
# 18      Fine if thatåÕs the way u feel ThatåÕs the way...
# 76      Thats cool i am a gentleman and will treat you...
# 693     Will purchase d stuff today and mail to you Do...
# 4275             Can you please send me my aunty's number
# 1510    Peteis this your phone still Its Jenny from co...
# 1289    HeyGreat dealFarm tour 9am to 5pm 95pax 50 dep...
# 3453    I dont have any of your file in my bagi was in...
# 832     Dear Voucher Holder To claim this weeks offer ...
# 4134    No need to say anything to me I know i am an o...
# 3176                        In meeting da I will call you
# 2841                              aathiwhere are you dear
# 2848    YOUR CHANCE TO BE ON A REALITY FANTASY SHOW ca...
# 5       FreeMsg Hey there darling it's been 3 week's n...
# 405     Haha get used to driving to usf man I know a l...
# 1898                            I love working from home
# 747     U are subscribed to the best Mobile Content Se...
# Name: Email, Length: 5572, dtype: object

# %% [markdown]
# # Separação da base de dados em Treinamento e Teste na fração 3 para 1.

# %%
#75% dos dados para a parte Treinamento.
#25% dos dados para a parte Teste.

dados_treino = dados.iloc[:setenta_cinco]
dados_teste = dados.iloc[setenta_cinco:num]
dados_reais = dados.iloc[setenta_cinco:num]

# %% [markdown]
# # Probabilidade de  uma mensagem ser SPAM e Probabilidade de uma mensagem ser HAM

# %%
dados_teste = dados_teste.Email.values #Values retorna uma lista com os emails.

Spam = dados_treino.Email[dados_treino.Class == 'spam'].values
Ham = dados_treino.Email[dados_treino.Class == 'ham'].values

# Probabilidade de uma mensagem ser SPAM:

Pspam = (dados_treino.Email[dados_treino.Class == 'spam'].count()/dados_treino.Email.count())*100

# Probabilidade de uma mensagem ser HAM:

Pham = (dados_treino.Email[dados_treino.Class == 'ham'].count()/dados_treino.Email.count())*100

# %% [markdown]
# # Criação de uma lista que armazena as palavras do email

# %%
#SPAM
spam_words = []
ham_words = []
i = 0
while i < len(Spam):
    word = Spam[i].split()
    for j in word:
        if j.isdigit == True:
            pass
        if len(j) <= 3:
            pass
        else:
            spam_words.append(j)
    i+=1

# %%
#HAM
i = 0
while i < len(Ham):
    word = Ham[i].split()
    for j in word:
        if j.isdigit == True:
            pass
        if len(j) <= 3:
            pass
        else:
            ham_words.append(j)
    i+=1

# %% [markdown]
# # Criação de um dicionário

# %%
spam_dic = {}
for i in spam_words:
    n = 1
    if i in spam_dic:
        pass
    else:   
        for j in spam_words:
            if i == j:
                n += 1
            else:
                pass
        spam_dic[i] = (n + 1)/(len(spam_words)*2 + len(ham_words))
ham_dic = {}
for i in ham_words:
    n = 1
    if i in ham_dic:
        pass
    else:   
        for j in ham_words:
            if i == j:
                n += 1
            else:
                pass
        ham_dic[i] = (n + 1)/(len(ham_words)*2 + len(spam_words))

# %% [markdown]
# # CLassificação

# %%
def classificando(emails,spam,ham,Pspam,Pham,roc):
    classificados = {} #Devolve se o email é SPAM ou se o email é HAM
    for emailss in emails:
        pspam = Pspam
        pham = Pham
        email = str(emailss).split()
        
        for w in email: #probabilidade de uma palavra acontecer se a mensagem na base treinamento é considerada SPAM e HAM.
            if w in spam:
                pspam = pspam*spam[w]
            if w in ham:
                pham = pham*ham[w]
        if pspam > roc*(pspam + pham):
            classificados[emailss] = 'spam'
        else:
            classificados[emailss] = 'ham'
    return classificados

# %%
# Reestruturação dos dados teste
teste = []
for i in dados_teste:
    teste.append(i)
dados_teste = teste

# %%
#Guardando classificados e probabilidades em variáveis
roc = 0.5
tudo_certo = classificando(dados_teste,spam_dic,ham_dic,Pspam,Pham,roc)
tudo_certo
# Out:
# {'Moji just informed me that you saved our lives Thanks': 'spam',
#  'Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am11pm as you have WON a guaranteed å£1000 cash or å£5000 prize': 'ham',
#  'URGENT We are trying to contact U Todays draw shows that you have won a å£800 prize GUARANTEED Call 09050001295 from land line Claim A21 Valid 12hrs only': 'ham',
#  'Nice talking to you please dont forget my pix i want to see all of you': 'spam',
#  'Today is \\song dedicated day\\ Which song will u dedicate for me Send this to all ur valuable frnds but first rply me': 'spam',
#  "My friend she's studying at warwick we've planned to go shopping and to concert tmw but it may be canceled havn't seen for ages yeah we should get together sometime": 'spam',
#  'Yup Wun believe wat U really neva c e msg i sent shuhui': 'spam',
#  'Nohe joined today itself': 'spam',
#  "Just trying to figure out when I'm suppose to see a couple different people this week We said we'd get together but I didn't set dates": 'spam',
#  'You best watch what you say cause I get drunk as a motherfucker': 'spam',
#  'Yes there were many sweets': 'spam',
#  'K tell me anything about you': 'spam',
#  'Yo you at jp and hungry like a mofo': 'spam',
#  'Yep the great loxahatchee xmas tree burning of ltgt starts in an hour': 'spam',
#  'Free msg Sorry a service you ordered from 81303 could not be delivered as you do not have sufficient credit Please top up to receive the service': 'ham',
#  'Mmmmmmm snuggles into you deep contented sigh whispers I fucking love you so much I can barely stand it ': 'spam',
#  'Yes Rent is very expensive so its the way we save': 'spam',
#  "I've told him that i've returned it That should i re order it": 'spam',
#  'Well done ENGLAND Get the official poly ringtone or colour flag on yer mobile text TONE or FLAG to 84199 NOW Optout txt ENG STOP Box39822 W111WX å£150': 'ham',
#  'Shb b ok lor Thanx': 'spam',
#  'Did u find out what time the bus is at coz i need to sort some stuff out': 'ham',
#  'Phony å£350 award Todays Voda numbers ending XXXX are selected to receive a å£350 award If you have a match please call 08712300220 quoting claim code 3100 standard rates app': 'ham',
#  'Now project pa After that only i can come': 'spam',
#  '\\Im reaching in another 2 stops\\': 'spam',
#  "I'll see if I can swing by in a bit got some things to take care of here firsg": 'spam',
#  'Where do you need to go to get it': 'ham',
#  'Not for possession especially not first offense': 'spam',
#  'Hi Hope you had a good day Have a better night': 'ham',
#  'So when do you wanna gym harri': 'ham',
#  'Urgent Please call 09066612661 from landline å£5000 cash or a luxury 4 Canary Islands Holiday await collection TCs SAE award 20M12AQ 150ppm 16 ‰ÛÏ': 'ham',
#  'I am late I will be there at': 'ham',
#  'Thanks for your ringtone order ref number K718 Your mobile will be charged å£450 Should your tone not arrive please call customer services on 09065069120': 'ham',
#  'No wonder Cos i dun rem seeing a silver car But i thk i saw a black one': 'spam',
#  'Ahhhhjust woken uphad a bad dream about u thoso i dont like u right now i didnt know anything about comedy night but i guess im up for it': 'spam',
#  "Sorry battery died yeah I'm here": 'spam',
#  "Is ur changes 2 da report big Cos i've already made changes 2 da previous report": 'spam',
#  'I cant pick the phone right now Pls send a message': 'spam',
#  'East coast': 'spam',
#  'Shit that is really shocking and scary cant imagine for a second Def up for night out Do u think there is somewhere i could crash for night save on taxi': 'spam',
#  "Forgot to tell Ì smth Can Ì like number the sections so that it's clearer": 'spam',
#  'HouseMaid is the murderer coz the man was murdered on ltgt th January As public holiday all govtinstituitions are closedincluding post officeunderstand': 'spam',
#  'U can call me now': 'ham',
#  'Lol where do u come up with these ideas': 'spam',
#  "I think that tantrum's finished so yeah I'll be by at some point": 'spam',
#  'Hi baby ive just got back from work and i was wanting to see u allday I hope i didnt piss u off on the phone today If u are up give me a call xxx': 'spam',
#  'Messagesome text missing SenderName Missing Number Missing SentDate missing Missing U a lot thats y everything is missing sent via fullonsmscom': 'spam',
#  'Good evening this is roger How are you': 'ham',
#  'Geeeee Your internet is really bad today eh ': 'spam',
#  'No plm i will come da On the way': 'spam',
#  'Awesome think we can get an 8th at usf some time tonight': 'ham',
#  'He needs to stop going to bed and make with the fucking dealing': 'spam',
#  'Hi Mobile no ltgt has added you in their contact list on wwwfullonsmscom It s a great place to send free sms to people For more visit fullonsmscom': 'spam',
#  "I'm viveki got call from your number": 'ham',
#  "I'm so in love with you I'm excited each day i spend with you You make me so happy": 'spam',
#  "When people see my msgs They think Iam addicted to msging They are wrong Bcoz They don\\'t know that Iam addicted to my sweet Friends BSLVYL": 'spam',
#  'That said can you text him one more time': 'spam',
#  'What to think no one saying clearly Ok leave no need to ask her I will go if she come or not': 'spam',
#  'Me too watching surya movie only after 6 pm vijay movie POKKIRI': 'spam',
#  'I take it the post has come then You must have 1000s of texts now Happy reading My one from wiv hello caroline at the end is my favourite Bless him': 'spam',
#  "I'm at home Please call": 'ham',
#  'When should I come over': 'spam',
#  'Free video camera phones with Half Price line rental for 12 mths and 500 cross ntwk mins 100 txts Call MobileUpd8 08001950382 or Call2OptOut674': 'ham',
#  'Open rebtel with firefox When it loads just put plus sign in the user name place and it will show you two numbers The lower number is my number Once you pick that number the pin will display okay': 'spam',
#  'Good Morning plz call me sir': 'spam',
#  "Hi di is yijue we're meeting at 7 pm at esaplanade tonight": 'spam',
#  'Hey Why dont we just go watch x men and have lunch Haha ': 'spam',
#  'Oh thats late Well have a good night and i will give u a call tomorrow Iam now going to go to sleep night night': 'ham',
#  'No datoday also i forgot': 'spam',
#  'Kkits goodwhen are you going': 'ham',
#  'Your 2004 account for 07XXXXXXXXX shows 786 unredeemed points To claim call 08719181259 Identifier code XXXXX Expires 260305': 'ham',
#  'Why are u up so early': 'spam',
#  'No my blankets are sufficient thx': 'ham',
#  'Take something for pain If it moves however to any side in the next 6hrs see a doctor': 'spam',
#  'Still otside leu come 2morrow maga': 'spam',
#  'Yeah I imagine he would be really gentle Unlike the other docs who treat their patients like turkeys': 'spam',
#  'Sitting ard nothing to do lor U leh busy w work': 'spam',
#  "I'm home": 'ham',
#  "Sorry I can't help you on this": 'spam',
#  'We have to pick rayan macleran there': 'spam',
#  "FREE2DAY sexy St George's Day pic of JordanTxt PIC to 89080 dont miss out then every wk a saucy celeb4 more pics c PocketBabecouk 0870241182716 å£3wk": 'ham',
#  'Noi got rumour that you going to buy apartment in chennai': 'spam',
#  'Somebody should go to andros and steal ice': 'spam',
#  'Dear SirSalam AlaikkumPride and Pleasure meeting you today at the Tea ShopWe are pleased to send you our contact number at QatarRakhesh an IndianPls save our NumberRespectful Regards': 'spam',
#  'Both i shoot big loads so get ready': 'spam',
#  'Oh thanks a loti already bought 2 eggs ': 'spam',
#  'Hey You got any mail': 'spam',
#  'Good Morning my Dear Shijutta Have a great amp successful day': 'spam',
#  'U sick still can go shopping': 'spam',
#  'PRIVATE Your 2003 Account Statement for 07808 XXXXXX shows 800 unredeemed S I M points Call 08719899217 Identifier Code 41685 Expires 071104': 'ham',
#  'i am going to bed now prin': 'ham',
#  'Yup': 'ham',
#  'Ok is any problem to u frm him Wats matter': 'spam',
#  'Anything': 'spam',
#  'Urgent call 09066350750 from your landline Your complimentary 4 Ibiza Holiday or 10000 cash await collection SAE TCs PO BOX 434 SK3 8WP 150 ppm 18 ': 'ham',
#  '26th OF JULY': 'ham',
#  'Cos i want it to be your thing': 'ham',
#  "No chikku nt yet Ya i'm free": 'spam',
#  'Win the newest åÒHarry Potter and the Order of the Phoenix Book 5 reply HARRY answer 5 questions chance to be the first among readers': 'ham',
#  "Glad it went well come over at 11 then we'll have plenty of time before claire goes to work": 'spam',
#  'Ok then no need to tell me anything i am going to sleep good night': 'ham',
#  "I'm coming home 4 dinner": 'spam',
#  "U don't remember that old commercial": 'spam',
#  'Rofl betta invest in some anti aging products': 'spam',
#  "Hi frnd which is best way to avoid missunderstding wit our beloved one's": 'spam',
#  'Yup How Ì noe leh': 'ham',
#  'Aiyar hard 2 type U later free then tell me then i call n scold n tell u': 'spam',
#  'RECPT 13 You have ordered a Ringtone Your order is being processed': 'ham',
#  'U say leh Of course nothing happen lar Not say v romantic jus a bit only lor I thk e nite scenery not so nice leh': 'spam',
#  'Then we gotta do it after that': 'spam',
#  'Hey so this sat are we going for the intro pilates only Or the kickboxing too ': 'spam',
#  'K k sms chat with me': 'ham',
#  'Cool I am ltgt inches long hope you like them big': 'spam',
#  '08714712388 between 10am7pm Cost 10p': 'ham',
#  'Watch lor I saw a few swatch one i thk quite ok Ard 116 but i need 2nd opinion leh': 'spam',
#  'Did I forget to tell you I want you I need you I crave you But most of all I love you my sweet Arabian steed Mmmmmm Yummy': 'spam',
#  'OH YEAHAND HAV A GREAT TIME IN NEWQUAYSEND ME A POSTCARD 1 LOOK AFTER ALL THE GIRLS WHILE IM GONEU KNOW THE 1IM TALKIN BOUTxx': 'spam',
#  "Boo How's things I'm back at home and a little bored already ": 'ham',
#  'When i have stuff to sell ill tell you': 'spam',
#  'Want to send me a virtual hug I need one': 'ham',
#  "I don't quite know what to do I still can't get hold of anyone I cud pick you up bout 730pm and we can see if they're in the pub": 'spam',
#  'S sfirst timedhoni rocks': 'spam',
#  'What type of stuff do you sing': 'spam',
#  'I hope your alright babe I worry that you might have felt a bit desparate when you learned the job was a fake I am here waiting when you come back my love': 'spam',
#  'Shopping Eh ger i toking abt syd lehHaha': 'ham',
#  'URGENT We are trying to contact you Last weekends draw shows that you have won a å£900 prize GUARANTEED Call 09061701851 Claim code K61 Valid 12hours only': 'ham',
#  'THIS IS A LONG FUCKIN SHOWR': 'spam',
#  'What happen dear Why you silent I am tensed': 'spam',
#  'Fine am simply sitting': 'spam',
#  "It's that time of the week again ryan": 'ham',
#  "Friendship is not a game to play It is not a word to say It doesn\\'t start on March and ends on May It is tomorrow yesterday today and e": 'spam',
#  "Yup i'm still having coffee wif my frens My fren drove she'll give me a lift": 'spam',
#  'I love u 2 my little pocy bell I am sorry but I love u': 'spam',
#  "Join the UK's horniest Dogging service and u can have sex 2nite Just sign up and follow the instructions Txt ENTRY to 69888 now NytEC2A3LPmsg150p": 'ham',
#  'HmmBad newsHype park plaza 700 studio takenOnly left 2 bedrm900': 'spam',
#  'No need lar Jus testing e phone card Dunno network not gd i thk Me waiting 4 my sis 2 finish bathing so i can bathe Dun disturb u liao u cleaning ur room': 'spam',
#  'Ya but it cant display internal subs so i gotta extract them': 'spam',
#  "Then get some cash together and I'll text jason": 'spam',
#  'I know she called me': 'spam',
#  'Sorry sent blank msg again Yup but trying 2 do some serious studying now': 'spam',
#  'What Todaysundaysunday is holidayso no work': 'spam',
#  'Welcome to UKmobiledate this msg is FREE giving you free calling to 08719839835 Future mgs billed at 150p daily To cancel send \\go stop\\ to 89123': 'ham',
#  'You are being contacted by our Dating Service by someone you know To find out who it is call from your mobile or landline 09064017305 PoBox75LDNS7 ': 'ham',
#  'I sent you the prices and do you mean the ltgt g': 'spam',
#  'Ok but knackered Just came home and went to sleep Not good at this full time work lark': 'spam',
#  'Did you say bold then torch later Or one torch and 2bold': 'spam',
#  'Pls accept me for one day Or am begging you change the number': 'spam',
#  'He is there You call and meet him': 'ham',
#  "Sad story of a Man Last week was my b'day My Wife did'nt wish me My Parents forgot n so did my Kids I went to work Even my Colleagues did not wish As I entered my cabin my PA said '' Happy B'day Boss '' I felt special She askd me 4 lunch After lunch she invited me to her apartment We went there She said'' do u mind if I go into the bedroom for a minute '' ''OK'' I sed in a sexy mood She came out 5 minuts latr wid a caken My Wife My Parents My Kidz My Friends n My Colleagues All screaming SURPRISE and I was waiting on the sofa  ' NAKED": 'spam',
#  "What's up bruv hope you had a great break Do have a rewarding semester": 'spam',
#  "URGENT Last weekend's draw shows that you have won å£1000 cash or a Spanish holiday CALL NOW 09050000332 to claim TC RSTM SW7 3SS 150ppm": 'ham',
#  "It could work we'll reach a consensus at the next meeting": 'ham',
#  "Yup i've finished c Ì there": 'spam',
#  'Oh Icic K lor den meet other day': 'ham',
#  'Squeeeeeze This is christmas hug If u lik my frndshp den hug me back If u get 3 u r cute 6 u r luvd 9 u r so lucky None People hate u': 'spam',
#  "I haven't forgotten you i might have a couple bucks to send you tomorrow k I love ya too": 'spam',
#  'Night has ended for another day morning has come in a special way May you smile like the sunny rays and leaves your worries at the blue blue bay': 'spam',
#  "Sorry I'll call later": 'spam',
#  'Ya even those cookies have jelly on them': 'spam',
#  'Oi when you gonna ring': 'spam',
#  'Adult 18 Content Your video will be with you shortly': 'ham',
#  "Awesome lemme know whenever you're around": 'spam',
#  "Aight let me know when you're gonna be around usf": 'spam',
#  "He has lots of used ones babe but the model doesn't help Youi have to bring it over and he'll match it up": 'spam',
#  "5p 4 alfie Moon's Children in need song on ur mob Tell ur m8s Txt Tone charity to 8007 for Nokias or Poly charity for polys zed 08701417012 profit 2 charity": 'ham',
#  "Havent stuck at orchard in my dad's car Going 4 dinner now U leh So r they free tonight": 'spam',
#  "As per your request 'Maangalyam Alaipayuthe' has been set as your callertune for all Callers Press 9 to copy your friends Callertune": 'spam',
#  'Tmr timin still da same wat cos i got lesson until 6': 'spam',
#  "alright tyler's got a minor crisis and has to be home sooner than he thought so be here asap": 'spam',
#  'Sunshine Quiz Wkly Q Win a top Sony DVD player if u know which country the Algarve is in Txt ansr to 82277 å£150 SPTyrone': 'ham',
#  'She doesnt need any test': 'spam',
#  'Missed call alert These numbers called but left no message 07008009200': 'spam',
#  "Great I was getting worried about you Just know that a wonderful and caring person like you will have only the best in life Know that u r wonderful and God's love is yours": 'spam',
#  'URGENT We are trying to contact you Last weekends draw shows u have won a å£1000 prize GUARANTEED Call 09064017295 Claim code K52 Valid 12hrs 150p pm': 'ham',
#  "Think I could stop by in like an hour or so My roommate's looking to stock up for a trip": 'spam',
#  'U meet other fren dun wan meet me ah Muz b a guy rite': 'spam',
#  "Good morning my boytoy How's those yummy lips Where's my sexy buns now What do you do Do you think of me Do you crave me Do you need me ": 'spam',
#  'have you ever had one foot before': 'spam',
#  'Hui xin is in da lib': 'ham',
#  "Will do you gonna be at blake's all night I might be able to get out of here a little early": 'spam',
#  'Are you this much buzy': 'spam',
#  'Im just wondering what your doing right now': 'spam',
#  'We are okay Going to sleep now Later': 'spam',
#  "Horrible u eat macs eat until u forgot abt me already rite U take so long 2 reply I thk it's more toot than b4 so b prepared Now wat shall i eat": 'spam',
#  'Ohi asked for fun Hahatake care Ì': 'ham',
#  'I jokin oni lar ÌÏ busy then i wun disturb Ì': 'spam',
#  '\\NOT ENUFCREDEIT TOCALLSHALL ILEAVE UNI AT 6 GET A BUS TO YOR HOUSE\\': 'ham',
#  "I'm an actor When i work i work in the evening and sleep late Since i'm unemployed at the moment i ALWAYS sleep late When you're unemployed every day is saturday": 'spam',
#  'Convey my regards to him': 'spam',
#  'He says hi and to get your ass back to south tampa preferably at a kegger': 'spam',
#  'Can do lor': 'ham',
#  'Oh unintentionally not bad timing Great Fingers the trains play along Will give fifteen min warning': 'spam',
#  'THATåÕS ALRITE GIRL U KNOW GAIL IS NEVA WRONGTAKE CARE SWEET AND DONåÕT WORRYC U L8TR HUNLOVE Yaxxx': 'spam',
#  'Are you going to wipro interview today': 'spam',
#  "hows my favourite person today r u workin hard couldn't sleep again last nite nearly rang u at 430": 'spam',
#  'Haha yeah 2 oz is kind of a shitload': 'spam',
#  'Great News Call FREEFONE 08006344447 to claim your guaranteed å£1000 CASH or å£2000 gift Speak to a live operator NOW': 'ham',
#  'Dont think so It turns off like randomlly within 5min of opening': 'spam',
#  "Hey babe how's it going Did you ever figure out where your going for New Years ": 'ham',
#  "Do Ì all wan 2 meet up n combine all the parts How's da rest of da project going": 'spam',
#  'Tell me whos this pls': 'spam',
#  'Double mins and txts 4 6months FREE Bluetooth on Orange Available on Sony Nokia Motorola phones Call MobileUpd8 on 08000839402 or call2optoutN9DX': 'ham',
#  'Hai dear friends This is my new amp present number By Rajitha Raj Ranju': 'spam',
#  "Yup i'm elaborating on the safety aspects and some other issues": 'ham',
#  'Text her If she doesnt reply let me know so i can have her log in': 'spam',
#  "I thk Ì gotta go home by urself Cos i'll b going out shopping 4 my frens present ": 'spam',
#  'PRIVATE Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points To claim call 08719180248 Identifier Code 45239 Expires': 'ham',
#  'New car and house for my parentsi have only new job in hand': 'spam',
#  '2 and half years i missed your friendship': 'spam',
#  "No dude its not fakemy frnds got money thts y i'm reffering uif u member wit my mail link u vl be credited ltgt rs and il be getiing ltgt rsi can draw my acc wen it is ltgt rs": 'spam',
#  'Gud mrng dear hav a nice day': 'spam',
#  "2p per min to call Germany 08448350055 from your BT line Just 2p per min Check PlanetTalkInstantcom for info T's C's Text stop to opt out": 'ham',
#  'i can call in ltgt min if thats ok': 'spam',
#  'No Ill meet you in the library': 'spam',
#  "My love I hope your not doing anything drastic Don't you dare sell your pc or your phone ": 'spam',
#  'Hii got the money da': 'ham',
#  'Haha just kidding papa needs drugs': 'spam',
#  'Then its most likely called Mittelschmertz Google it If you dont have paracetamol dont worry it will go': 'spam',
#  "Y cant u try new invention to flyi'm not joking": 'spam',
#  "Why don't you go tell your friend you're not sure you want to live with him because he smokes too much then spend hours begging him to come smoke": 'spam',
#  "I'm going 2 orchard now laready me reaching soon U reaching": 'spam',
#  'Kothi print out marandratha': 'spam',
#  "No promises on when though haven't even gotten dinner yet": 'spam',
#  "Well there's a pattern emerging of my friends telling me to drive up and come smoke with them and then telling me that I'm a weed fiendmake them smoke too muchimpede their doing other things so you see how I'm hesitant": 'spam',
#  'Customer place i will call you': 'ham',
#  "It's ok at least armand's still around": 'spam',
#  'Good words But words may leave u in dismay many times': 'spam',
#  'Yessura in sun tvlol': 'ham',
#  'Anything lor U decide': 'spam',
#  'Its a valentine game  Send dis msg to all ur friends If 5 answers r d same then someone really loves u Ques which colour suits me the bestrply me': 'spam',
#  'IM LATE TELLMISS IM ON MY WAY': 'spam',
#  'They will pick up and drop in carso no problem': 'spam',
#  "\\SYMPTOMS\\ when U are in love \\1U like listening songs 2U get stopped where u see the name of your beloved 3U won't get angry when your": 'spam',
#  'Taka lor Wat time u wan 2 come n look 4 us': 'spam',
#  'Yup song bro No creative Neva test quality He said check review online': 'spam',
#  'Good evening Sir Al Salam Wahleykkumsharing a happy newsBy the grace of God i got an offer from TayseerTISSCO and i joinedHope you are fineInshah Allahmeet you sometimeRakheshvisitor from India': 'spam',
#  'i cant talk to you nowi will call when i candont keep calling': 'spam',
#  'O ic lol Should play 9 doors sometime yo': 'spam',
#  'Ummmmmaah Many many happy returns of d day my dear sweet heart HAPPY BIRTHDAY dear': 'spam',
#  'Dont you have message offer': 'ham',
#  "Well she's in for a big surprise": 'spam',
#  "123 Congratulations in this week's competition draw u have won the å£1450 prize to claim just call 09050002311 b4280703 TCsstop SMS 08718727868 Over 18 only 150ppm": 'ham',
#  "Freemessage JamsterGet the crazy frog sound now For poly text MAD1 for real text MAD2 to 88888 6 crazy sounds for just 3 GBPweek 16only TC's apply": 'ham',
#  'You have WON a guaranteed å£1000 cash or a å£2000 prize To claim yr prize call our customer service representative on 08714712379 between 10am7pm Cost 10p': 'ham',
#  "Tired I haven't slept well the past few nights": 'spam',
#  'Love it I want to flood that pretty pussy with cum': 'spam',
#  'Want the latest Video handset 750 anytime any network mins Half price line rental Reply or call 08000930705 for delivery tomorrow': 'ham',
#  'It does it on its own Most of the time it fixes my spelling But sometimes it gets a completely diff word Go figure': 'spam',
#  'Arun can u transfr me d amt': 'spam',
#  'Especially since i talk about boston all up in my personal statement lol I woulda changed that if i had realized it said nyc It says boston now': 'spam',
#  'Long time You remember me today': 'spam',
#  "Carlos says he'll be at mu in ltgt minutes": 'spam',
#  "Erm ‰Û ill pick you up at about 645pm That'll give enough time to get there park and that": 'spam',
#  'Anytime lor': 'spam',
#  'Good day to You tooPray for meRemove the teeth as its painful maintaining other stuff': 'spam',
#  'How is my boy No sweet words left for me this morning sighs How goes you day my love Did you start your studying': 'spam',
#  'Hahahause your brain dear': 'spam',
#  'I‰Û÷ve got some salt you can rub it in my open wounds if you like': 'ham',
#  'URGENT Your Mobile No was awarded å£2000 Bonus Caller Prize on 5903 This is our final try to contact U Call from Landline 09064019788 BOX42WR29C 150PPM': 'ham',
#  'I doubt you could handle 5 times per night in any case': 'spam',
#  'Ok': 'ham',
#  "Hasn't that been the pattern recently crap weekends": 'spam',
#  'URGENT Your Mobile number has been awarded with a å£2000 prize GUARANTEED Call 09058094455 from land line Claim 3030 Valid 12hrs only': 'ham',
#  'Latest News Police station toilet stolen cops have nothing to go on': 'spam',
#  'Thts wat Wright Brother did to fly': 'spam',
#  'Perhaps is much easy give your account identification so i will tomorrow at UNI': 'ham',
#  "I'll reach in ard 20 mins ok": 'spam',
#  'As a Registered Subscriber yr draw 4 a å£100 gift voucher will b entered on receipt of a correct ans When are the next olympics Txt ans to 80062': 'ham',
#  'No messageno responcewhat happend': 'spam',
#  "Mystery solved Just opened my email and he's sent me another batch Isn't he a sweetie": 'spam',
#  'Hottest pics straight to your phone See me getting Wet and Wanting just for you xx Text PICS to 89555 now txt costs 150p textoperator g696ga 18 XxX': 'ham',
#  "Yeah I think my usual guy's still passed out from last night if you get ahold of anybody let me know and I'll throw down": 'spam',
#  'That was random saw my old roomate on campus He graduated': 'spam',
#  'LOL Have you made plans for new years': 'spam',
#  'Try neva mate': 'spam',
#  'I will see in half an hour': 'spam',
#  'I sent you ltgt bucks': 'spam',
#  "Me sef dey laugh you Meanwhile how's my darling anjie": 'spam',
#  'Hi can i please get a ltgt dollar loan from you Ill pay you back by mid february Pls': 'spam',
#  "Gumby's has a special where a ltgt \\ cheese pizza is 2 so I know what we're doin tonight": 'spam',
#  'Apart from the one i told you about yesterday': 'spam',
#  'Where is that one day training': 'spam',
#  'I know complain num onlybettr directly go to bsnl offc nd apply for it': 'ham',
#  "Realy sorryi don't recognise this number and am now confused who r u please ": 'spam',
#  'Maybe westshore or hyde park village the place near my house': 'spam',
#  'We are both fine Thanks': 'spam',
#  'Then dun wear jeans lor': 'spam',
#  'Cos i was out shopping wif darren jus now n i called him 2 ask wat present he wan lor Then he started guessing who i was wif n he finally guessed darren lor': 'spam',
#  'How r Ì going to send it to me': 'ham',
#  'Ssindia going to draw the series after many years in south african soil': 'spam',
#  "If you don't respond imma assume you're still asleep and imma start calling n shit": 'spam',
#  "I guess that's why you re worried You must know that there's a way the body repairs itself And i'm quite sure you shouldn't worry We'll take it slow First the tests they will guide when your ovulation is then just relax Nothing you've said is a reason to worry but ill keep on followin you up": 'spam',
#  'Thank you I like you as well': 'spam',
#  'Nationwide auto centre or something like that on Newport road I liked them there': 'spam',
#  'Lol U drunkard Just doing my hair at d moment Yeah still up 4 tonight Wats the plan ': 'spam',
#  'Today am going to college so am not able to atten the class': 'spam',
#  'Kgive back my thanks': 'ham',
#  "Thank you so much When we skyped wit kz and sura we didnt get the pleasure of your company Hope you are good We've given you ultimatum oh We are countin down to aburo Enjoy This is the message i sent days ago": 'spam',
#  "I know I'm lacking on most of this particular dramastorm's details but for the most part I'm not worried about that": 'ham',
#  'Yup leaving right now be back soon': 'spam',
#  'Kall the bestcongrats': 'ham',
#  "My Parents My Kidz My Friends n My Colleagues All screaming SURPRISE and I was waiting on the sofa  ' NAKED": 'spam',
#  'Knock Knock Txt whose there to 80082 to enter r weekly draw 4 a å£250 gift voucher 4 a store of yr choice TCs wwwtklscom age16 to stoptxtstopå£150week': 'ham',
#  'Ya tel wats ur problem': 'spam',
#  'How are you Wish you a great semester': 'spam',
#  'Yo you guys ever figure out how much we need for alcohol Jay and I are trying to figure out how much we can safely spend on weed': 'spam',
#  'What happen to her tell the truth': 'spam',
#  'Yes I come to nyc for audiitions and am trying to relocate': 'spam',
#  'Does uncle timi help in clearing cars': 'spam',
#  'How come u got nothing to do': 'spam',
#  "Oh fine I'll be by tonight": 'spam',
#  'Ill be at yours in about 3 mins but look out for me': 'ham',
#  'Great Hope you are using your connections from mode men also cos you can never know why old friends can lead you to today': 'spam',
#  "I don't have anybody's number I still haven't thought up a tactful way to ask alex": 'ham',
#  'Ur cashbalance is currently 500 pounds to maximize ur cashin now send GO to 86688 only 150pmsg CC 08718720201 HGSuite3422Lands RowW1J6HL': 'ham',
#  ' and picking them up from various points | going 2 yeovil | and they will do the motor project 4 3 hours | and then u take them home || 12 2 530 max || Very easy': 'spam',
#  'Erm I thought the contract ran out the4th of october': 'ham',
#  'Thanks for the Vote Now sing along with the stars with Karaoke on your mobile For a FREE link just reply with SING now': 'spam',
#  "Nope i'll come online now": 'spam',
#  "Jay says that you're a doublefaggot": 'spam',
#  "Wat makes u thk i'll fall down But actually i thk i'm quite prone 2 falls Lucky my dad at home i ask him come n fetch me already": 'spam',
#  'Yesterday its with me only Now am going home': 'ham',
#  'My life Means a lot to me Not because I love my life But because I love the people in my life The world calls them friends I call them my World Ge': 'ham',
#  "I've not sent it He can send me": 'ham',
#  'How are you my Love Are you with your brother Time to talk english with him grins Say Hey Muhommad Penny says hello from across the sea': 'spam',
#  "Forgot you were working today Wanna chat but things are ok so drop me a text when you're free bored etc and i'll ring Hope all is well nose essay and all xx": 'spam',
#  "it's really getting me down just hanging around": 'spam',
#  'You sure your neighbors didnt pick it up': 'spam',
#  'Please call our customer service representative on 0800 169 6031 between 10am9pm as you have WON a guaranteed å£1000 cash or å£5000 prize': 'ham',
#  'Lara said she can loan me ltgt ': 'spam',
#  'Oh and by the way you do have more food in your fridge Want to go out for a meal tonight ': 'spam',
#  " yeah Lol Luckily i didn't have a starring role like you": 'spam',
#  'Neshanthtel me who r u': 'ham',
#  "Finally it has happened Aftr decades BEER is now cheaper than PETROL The goverment expects us to \\DRINK\\  But don't \\DRIVE \\": 'spam',
#  'Tell them u have a headache and just want to use 1 hour of sick time': 'spam',
#  'The message sent is askin for ltgt dollars Shoul i pay ltgt or ltgt ': 'spam',
#  'Never blame a day in ur life Good days give u happiness Bad days give u experience Both are essential in life All are Gods blessings good morning': 'spam',
#  'Sos Any amount i can get pls': 'spam',
#  '\\BOO BABE U ENJOYIN YOURJOB U SEEMED 2 B GETTIN ON WELL HUNNYHOPE URE OKTAKE CARE IåÕLLSPEAK 2U SOONLOTS OF LOVEME XXXX\\': 'spam',
#  'Or i go home first lar Ì wait 4 me lor I put down my stuff first': 'ham',
#  'Pls i wont belive godnot only jesus': 'spam',
#  "Eek that's a lot of time especially since American Pie is like 8 minutes long I can't stop singing it": 'spam',
#  'Come to me right now Ahmad': 'spam',
#  'I have no idea where you are': 'spam',
#  "K my roommate also wants a dubsack and another friend may also want some so plan on bringing extra I'll tell you when they know for sure": 'spam',
#  'K dahow many page you want': 'spam',
#  'Sno competition for him': 'ham',
#  "You've won tkts to the EURO2004 CUP FINAL or å£800 CASH to collect CALL 09058099801 b4190604 POBOX 7876150ppm": 'ham',
#  'The Xmas story is peace The Xmas msg is love The Xmas miracle is jesus Hav a blessed month ahead amp wish U Merry Xmas': 'spam',
#  'Haha dont be angry with yourself Take it as a practice for the real thing ': 'spam',
#  'Dont gimme that lip caveboy': 'ham',
#  'Ok lor': 'ham',
#  'Alrite jod hows the revision goin Keris bin doin a smidgin N e way u wanna cum over after collegexx': 'spam',
#  'Sian Aft meeting supervisor got work 2 do liao U working now': 'spam',
#  'complimentary 4 STAR Ibiza Holiday or å£10000 cash needs your URGENT collection 09066364349 NOW from Landline not to lose out Box434SK38WP150PPM18': 'ham',
#  'Actually i deleted my old websitenow i m blogging at magicalsongsblogspotcom': 'spam',
#  'R U SAM P IN EACHOTHER IF WE MEET WE CAN GO 2 MY HOUSE': 'spam',
#  'At home watching tv lor': 'spam',
#  'Are you ok What happen to behave like this': 'spam',
#  'How come it takes so little time for a child who is afraid of the dark to become a teenager who wants to stay out all night': 'spam',
#  'Ur cashbalance is currently 500 pounds to maximize ur cashin now send GO to 86688 only 150pmeg CC 08718720201 HGSuite3422lands RowW1j6HL': 'ham',
#  "Yes but I don't care cause I know its there": 'ham',
#  '500 New Mobiles from 2004 MUST GO Txt NOKIA to No 89545 collect yours todayFrom ONLY å£1 www4tcbiz 2optout 08718726270150gbpmtmsg18 TXTAUCTION': 'ham',
#  "Aight text me tonight and we'll see what's up": 'spam',
#  "Stop the story I've told him i've returned it and he's saying i should not re order it": 'spam',
#  "Where are you What are you doing Are yuou working on getting the pc to your mom's Did you find a spot that it would work I need you": 'spam',
#  "Yunny i'm walking in citylink now Ì faster come down Me very hungry": 'spam',
#  'Yeshe is really greatbhaji told kallis best cricketer after sachin in worldvery tough to get out': 'spam',
#  'I‰Û÷m going to try for 2 months ha ha only joking': 'spam',
#  'We r outside already': 'spam',
#  "You didn't have to tell me thatnow i'm thinking Plus he's going to stop all your runs": 'spam',
#  '<Forwarded from 448712404000>Please CALL 08712404000 immediately as there is an urgent message waiting for you': 'ham',
#  'When are you guys leaving': 'spam',
#  'Ok ÌÏ finishing soon': 'spam',
#  'U calling me right Call my hand phone': 'spam',
#  "I've told you everything will stop Just dont let her get dehydrated": 'spam',
#  'Carry on not disturbing both of you': 'spam',
#  "What do u reckon as need 2 arrange transport if u can't do it thanks": 'spam',
#  'Great comedycant stop laughing da': 'spam',
#  'FREE MESSAGEThanks for using the Auction Subscription Service 18 150pMSGRCVD 2 Skip an Auction txt OUT 2 Unsubscribe txt STOP CustomerCare 08718726270': 'ham',
#  'Probably gonna swing by in a wee bit': 'spam',
#  'And smile for me right now as you go and the world will wonder what you are smiling about and think your crazy and keep away from you grins': 'spam',
#  'Do well all will for little time Thing of good times ahead': 'spam',
#  "Nah I don't think he goes to usf he lives around here though": 'spam',
#  'So u gonna get deus ex': 'spam',
#  'No but the bluray player can': 'ham',
#  'Depends on quality If you want the type i sent boye faded glory then about 6 If you want ralphs maybe 2': 'spam',
#  "Slaaaaave Where are you Must I summon you to me all the time now Don't you wish to come to me on your own anymore": 'spam',
#  'URGENT Your Mobile No was awarded a å£2000 Bonus Caller Prize on 10803 This is our 2nd attempt to contact YOU Call 08714719523 BOX95QU BT National Rate': 'ham',
#  'Please CALL 08712402902 immediately as there is an urgent message waiting for you': 'ham',
#  'Get ready for ltgt inches of pleasure': 'spam',
#  'It means u could not keep ur words': 'spam',
#  'His bday real is in april ': 'spam',
#  'Mum say we wan to go then go Then she can shun bian watch da glass exhibition ': 'spam',
#  'This message is free Welcome to the new improved Sex Dogging club To unsubscribe from this service reply STOP msgs150p 18 only': 'ham',
#  'I love ya too but try and budget your money better babe Gary would freak on me if he knew': 'spam',
#  'Wen ur lovable bcums angry wid u dnt take it seriously Coz being angry is d most childish n true way of showing deep affection care n luv kettoda manda Have nice day da': 'spam',
#  'I love to give massages I use lots of baby oil What is your fave position': 'spam',
#  'Blank is Blank But wat is blank Lol': 'ham',
#  'Waiting for your call': 'spam',
#  "I'm home Doc gave me pain meds says everything is fine": 'spam',
#  'Call me I m unable to cal Lets meet bhaskar and deep': 'spam',
#  "I'm going out to buy mum's present ar": 'spam',
#  "Don't forget who owns you and who's private property you are And be my good boy always passionate kiss": 'spam',
#  '<Forwarded from 21870000>Hi this is your Mailbox Messaging SMS alert You have 4 messages You have 21 matches Please call back on 09056242159 to retrieve your messages and matches': 'ham',
#  'Dear i have reache room': 'spam',
#  'Wish u many many returns of the day Happy birthday vikky': 'spam',
#  'Dear got train and seat mine lower seat': 'spam',
#  'I meant middle left or right': 'spam',
#  'Did u download the fring app': 'ham',
#  'SO IS TH GOWER MATE WHICH IS WHERE I AM HOW R U MAN ALL IS GOOD IN WALES ILL B BACK åÔMORROW C U THIS WK WHO WAS THE MSG 4 åÐ RANDOM': 'spam',
#  'YOU HAVE WON As a valued Vodafone customer our computer has picked YOU to win a å£150 prize To collect is easy Just call 09061743386 ': 'ham',
#  'Dunno lei I might b eatin wif my frens If Ì wan to eat then i wait 4 Ì lar': 'spam',
#  'You will be in the place of that man': 'ham',
#  "Loan for any purpose å£500 å£75000 Homeowners Tenants welcome Have you been previously refused We can still help Call Free 0800 1956669 or text back 'help'": 'ham',
#  'FREE for 1st week No1 Nokia tone 4 ur mob every week just txt NOKIA to 87077 Get txting and tell ur mates zed POBox 36504 W45WQ norm150ptone 16': 'ham',
#  'Its worse if if uses half way then stops Its better for him to complete it': 'spam',
#  'I have a rather prominent bite mark on my right cheek': 'spam',
#  'Hmmmkbut i want to change the field quickly dai wanna get system administrator or network administrator': 'spam',
#  'How are you holding up': 'spam',
#  'Ahhh Work I vaguely remember that What does it feel like Lol': 'spam',
#  "Y she dun believe leh I tot i told her it's true already I thk she muz c us tog then she believe": 'ham',
#  'My slave I want you to take 2 or 3 pictures of yourself today in bright light on your cell phone Bright light': 'spam',
#  'The beauty of life is in next second which hides thousands of secrets I wish every second will be wonderful in ur life gud n8': 'spam',
#  'Gr8 Poly tones 4 ALL mobs direct 2u rply with POLY TITLE to 8007 eg POLY BREATHE1 Titles CRAZYIN SLEEPINGWITH FINEST YMCA getzedcouk POBox365O4W45WQ 300p': 'ham',
#  "For ur chance to win a å£250 cash every wk TXT ACTION to 80608 T'sC's wwwmovietriviatv custcare 08712405022 1x150pwk": 'ham',
#  'There is os called ubandu which will run without installing in hard diskyou can use that os to copy the important files in system and give it to repair shop': 'spam',
#  "Cool I'll text you in a few": 'spam',
#  'God created gap btwn ur fingers so dat sum1 vry special will fill those gaps by holding ur hands Now plz dont ask y he created so much gap between legs ': 'spam',
#  'U were outbid by simonwatson5120 on the Shinco DVD Plyr 2 bid again visit sms acsmsrewards 2 end bid notifications reply END OUT': 'ham',
#  'Haha awesome I might need to take you up on that what you doin tonight': 'spam',
#  'I attended but nothing is there': 'ham',
#  'Free entry to the gr8prizes wkly comp 4 a chance to win the latest Nokia 8800 PSP or å£250 cash every wkTXT GREAT to 80878 httpwwwgr8prizescom 08715705022': 'ham',
#  'Yeah confirmed for you staying at that weekend': 'spam',
#  "Go chase after her and run her over while she's crossing the street": 'spam',
#  'Where can download clear movies Dvd copies': 'spam',
#  'But you dint in touch with me': 'spam',
#  'What about this one then': 'ham',
#  'Nobut heard abt tat': 'ham',
#  'If you still havent collected the dough pls let me know so i can go to the place i sent it to get the control number': 'spam',
#  'Why you Dint come with us': 'spam',
#  'Chk in ur belovd ms dict': 'ham',
#  'That seems unnecessarily hostile': 'spam',
#  '449071512431 URGENT This is the 2nd attempt to contact UU have WON å£1250 CALL 09071512433 b4 050703 TCsBCM4235WC1N3XX callcost 150ppm mobilesvary maxå£7 50': 'ham',
#  'WOT U WANNA DO THEN MISSY': 'spam',
#  'Moby Pub QuizWin a å£100 High Street prize if u know who the new Duchess of Cornwall will be Txt her first name to 82277unsub STOP å£150 008704050406 SP Arrow': 'ham',
#  'So now my dad is gonna call after he gets out of work and ask all these crazy questions': 'spam',
#  'Guess he wants alone time We could just show up and watch when they do': 'spam',
#  "Jay's getting really impatient and belligerent": 'spam',
#  'Frnd s not juz a wordnot merely a relationshipits a silent promise which says \\ I will be with YOU \\ Wherevr Whenevr Forevr Gudnyt dear': 'spam',
#  'Now whats your house again And do you have any beer there ': 'ham',
#  "Let's pool our money together and buy a bunch of lotto tickets If we win I get ltgt u get ltgt Deal": 'spam',
#  'Goodmorning today i am late for ltDECIMALgt min': 'spam',
#  'Ok Thanx Gd nite 2 Ì too': 'spam',
#  "I'll let you know when it kicks in": 'spam',
#  'Hey u still at the gym': 'ham',
#  'December only Had your mobile 11mths You are entitled to update to the latest colour camera mobile for Free Call The Mobile Update VCo FREE on 08002986906 ': 'ham',
#  'I hope your pee burns tonite': 'spam',
#  'Howz that persons story': 'spam',
#  'I finished my lunch already U wake up already': 'spam',
#  "Oh yeah clearly it's my fault": 'spam',
#  'You still coming tonight': 'spam',
#  "The gas station is like a block away from my house you'll drive right by it since armenia ends at swann and you have to take howard": 'spam',
#  "Aight you close by or still down around alex's place": 'spam',
#  'Congratulations Thanks to a good friend U have WON the å£2000 Xmas prize 2 claim is easy just call 08718726978 NOW Only 10p per minute BTnationalrate': 'ham',
#  'cool We will have fun practicing making babies': 'spam',
#  "Babe I'm answering you can't you see me Maybe you'd better reboot YM I got the photo It's great ": 'spam',
#  'That means you got an A in epi shes fine Shes here now': 'spam',
#  'Omg I want to scream I weighed myself and I lost more weight Woohoo': 'spam',
#  'i am seeking a lady in the street and a freak in the sheets Is that you': 'spam',
#  'Beauty sleep can help ur pimples too': 'spam',
#  'Final Chance Claim ur å£150 worth of discount vouchers today Text YES to 85023 now SavaMob member offers mobile T Cs SavaMob POBOX84 M263UZ å£300 Subs 16': 'ham',
#  'Purity of friendship between two is not about smiling after reading the forwarded messageIts about smiling just by seeing the name Gud evng': 'spam',
#  'Water logging in desert Geoenvironmental implications': 'spam',
#  "Si'm watching it in live": 'spam',
#  'Sounds like you have many talents would you like to go on a dinner date next week': 'spam',
#  "I dont think so You don't need to be going out that late on a school night ESPECIALLY when the one class you have is the one you missed last wednesday and probably failed a test in on friday": 'spam',
#  "Orange customer you may now claim your FREE CAMERA PHONE upgrade for your loyalty Call now on 0207 153 9996 Offer ends 14thMarch TC's apply Optout availa": 'ham',
#  'The world is running and i am stillmaybe all are feeling the sameso be itor i have to admiti am madthen where is the correctionor let me call this is lifeand keep running with the worldmay be u r also runninglets run': 'spam',
#  "Thank you so much When we skyped wit kz and sura we didnt get the pleasure of your company Hope you are good We've given you ultimatum oh We are countin down to aburo Enjoy": 'spam',
#  'URGENT You have won a 1 week FREE membership in our å£100000 Prize Jackpot Txt the word CLAIM to No 81010 TC wwwdbuknet LCCLTD POBOX 4403LDNW1A7RW18': 'ham',
#  'How much you got for cleaning': 'spam',
#  'ltgt ISH MINUTES WAS 5 MINUTES AGO WTF': 'spam',
#  'TaKe CaRE n gET WeLL sOOn': 'spam',
#  'Wewa is 130 Iriver 255 All 128 mb': 'ham',
#  'Hi its LUCY Hubby at meetins all day Fri I will B alone at hotel U fancy cumin over Pls leave msg 2day 09099726395 Lucy x Callså£1minMobsmoreLKPOBOX177HP51FL': 'ham',
#  'Later i guess I needa do mcat study too': 'spam',
#  'Fuck babe What happened to you How come you never came back': 'spam',
#  "Pls tell nelson that the bb's are no longer comin The money i was expecting aint coming": 'spam',
#  'Tee hee Off to lecture cheery bye bye': 'spam',
#  "Hey i've booked the 2 lessons on sun liao": 'spam',
#  'Babe How goes that day What are you doing Where are you I sip my cappuccino and think of you my love I send a kiss to you from across the sea': 'spam',
#  '2marrow only Wed at ltgt to 2 aha': 'spam',
#  'Yes fine ': 'spam',
#  'Hi PeteynoiåÕm ok just wanted 2 chat coz avent spoken 2 u 4 a long timehope ur doin alritehave good nit at js love ya amx': 'spam',
#  'All e best 4 ur exam later': 'spam',
#  'My battery is low babe': 'spam',
#  'Okie': 'spam',
#  'In life when you face choices Just toss a coin not becoz its settle the question But while the coin in the air U will know what your heart is hoping for Gudni8': 'spam',
#  'Haha that was the first person I was gonna ask': 'spam',
#  'Sorry || mail || ': 'spam',
#  'Not heard from U4 a while Call 4 rude chat private line 01223585334 to cum Wan 2C pics of me gettin shagged then text PIX to 8552 2End send STOP 8552 SAM xxx': 'spam',
#  'Urgent UR awarded a complimentary trip to EuroDisinc Trav AcoEntry41 Or å£1000 To claim txt DIS to 87121 186å£150moreFrmMob ShrAcomOrSglSuplt10 LS1 3AJ': 'ham',
#  'Yes Last practice': 'ham',
#  'Ya very nice be ready on thursday': 'spam',
#  'Not from this campus Are you in the library': 'spam',
#  "Kaiez Enjoy ur tuition Gee Thk e second option sounds beta I'll go yan jiu den msg u": 'spam',
#  "The table's occupied I'm waiting by the tree": 'spam',
#  'Do you work all this week ': 'ham',
#  'Here is your discount code RP176781 To stop further messages reply stop wwwregalportfoliocouk Customer Services 08717205546': 'spam',
#  '4mths half price Orange line rental latest camera phones 4 FREE Had your phone 11mths Call MobilesDirect free on 08000938767 to update now or2stoptxt': 'ham',
#  "K fyi I'm back in my parents' place in south tampa so I might need to do the deal somewhere else": 'spam',
#  'Maybe Say hi to and find out if got his card Great escape or wetherspoons ': 'spam',
#  'K I will sent it again': 'ham',
#  'They released vday shirts and when u put it on it makes your bottom half naked instead of those white underwear': 'spam',
#  'Dare i ask Any luck with sorting out the car': 'spam',
#  "I'm in inside officestill filling formsdon know when they leave me": 'ham',
#  "I'm back lemme know when you're ready": 'ham',
#  'Hi the SEXYCHAT girls are waiting for you to text them Text now for a great night chatting send STOP to stop this service': 'ham',
#  'Urgh coach hot smells of chip fat Thanks again especially for the duvet not a predictive text word': 'spam',
#  'Oh yeah And my diet just flew out the window': 'spam',
#  'If you wereare free i can give Otherwise nalla adi entey nattil kittum': 'spam',
#  "But that's on ebay it might be less elsewhere": 'spam',
#  "Nobody names their penis a girls name this story doesn't add up at all": 'spam',
#  'Kkany special today': 'ham',
#  'Aight sounds good When do you want me to come down': 'spam',
#  'That day Ì say Ì cut ur hair at paragon is it called hair sense Do Ì noe how much is a hair cut ': 'spam',
#  'Tessypls do me a favor Pls convey my birthday wishes to Nimyapls dnt forget it Today is her birthday Shijas': 'spam',
#  'Hi dis is yijue i would be happy to work wif Ì all for gek1510': 'spam',
#  'Ok lor then we go tog lor': 'ham',
#  'Yes my reg is Ciao': 'ham',
#  'Are u awake Is there snow there': 'spam',
#  'Goodmorning sleeping ga': 'spam',
#  'Ok cool See ya then': 'ham',
#  'Ranjith cal drpd Deeraj and deepak 5min hold': 'spam',
#  "Lol your right What diet Everyday I cheat anyway I'm meant to be a fatty ": 'spam',
#  'You bad girl I can still remember them': 'ham',
#  "He didn't see his shadow We get an early spring yay": 'spam',
#  "Me i'm not workin Once i get job": 'spam',
#  'K give me a sec breaking a ltgt at cstore': 'spam',
#  'Ur cashbalance is currently 500 pounds to maximize ur cashin now send GO to 86688 only 150pmsg CC 08718720201 PO BOX 11414 TCRW1': 'ham',
#  'The new deus ex game comin early next yr': 'spam',
#  "Time n Smile r the two crucial things in our life Sometimes time makes us to forget smile and sometimes someone's smile makes us to forget time gud noon": 'spam',
#  'I am getting threats from your sales executive Shifad as i raised complaint against him Its an official message': 'spam',
#  'No no I will check all rooms befor activities': 'spam',
#  'Tell rob to mack his gf in the theater': 'ham',
#  'WHITE FUDGE OREOS ARE IN STORES': 'ham',
#  'Multiply the numbers independently and count decimal points then for the division push the decimal places like i showed you': 'spam',
#  'Hello thanx for taking that call I got a job Starts on monday': 'spam',
#  'FreeMsg Claim ur 250 SMS messagesText OK to 84025 nowUse web2mobile 2 ur mates etc Join Txt250com for 150pwk TC BOX139 LA32WU 16 Remove txtX or stop': 'ham',
#  "I'm in town now so i'll jus take mrt down later": 'spam',
#  "I'm done oredi": 'spam',
#  'Hey pple700 or 900 for 5 nightsExcellent location wif breakfast hamper': 'spam',
# ...
#  'You have 1 new message Please call 08718738034': 'ham',
#  'I dont know exactly could you ask chechi': 'spam',
#  "Sorryin meeting I'll call later": 'spam',
#  "Usually the person is unconscious that's in children but in adults they may just behave abnormally Ill call you now": 'spam',
#  'Hmm Bits and pieces lol sighs ': 'spam',
#  'Is there any movie theatre i can go to and watch unlimited movies and just pay once': 'spam',
#  'Sez hows u de arab boy Hope u r all good give my love 2 evry1 love ya eshxxxxxxxxxxx': 'ham',
#  'Todays Voda numbers ending with 7634 are selected to receive a å£350 reward If you have a match please call 08712300220 quoting claim code 7684 standard rates apply': 'ham',
#  '22 days to kick off For Euro2004 U will be kept up to date with the latest news and results daily To be removed send GET TXT STOP to 83222': 'ham',
#  'Haha awesome omw back now then': 'spam',
#  'Why must we sit around and wait for summer days to celebrate Such a magical sight when the worlds dressed in white Oooooh let there be snow': 'spam',
#  "I'll see but prolly yeah": 'spam',
#  'You please give us connection today itself before ltDECIMALgt or refund the bill': 'spam',
#  'Haha They cant what At the most tmr forfeit haha so how': 'spam',
#  'They can try They can get lost in fact Tee hee': 'spam',
#  'Set a place for me in your heart and not in your mind as the mind easily forgets but the heart will always remember Wish you Happy Valentines Day': 'spam',
#  'How long before you get reply just defer admission til next semester': 'spam',
#  'Had your mobile 10 mths Update to the latest CameraVideo phones for FREE KEEP UR SAME NUMBER Get extra free minstexts Text YES for a call': 'spam',
#  'Dunno he jus say go lido Same time 930': 'spam',
#  'Haha just what I was thinkin': 'spam',
#  'Buy Space Invaders 4 a chance 2 win orig Arcade Game console Press 0 for Games Arcade std WAP charge See o2coukgames 4 Terms settings No purchase': 'ham',
#  'I luv u soo much u donåÕt understand how special u r 2 me ring u 2morrow luv u xxx': 'spam',
#  "That's a shame Maybe cld meet for few hrs tomo": 'spam',
#  "Yup no need I'll jus wait 4 e rain 2 stop": 'spam',
#  'ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE MINS INDIA CUST SERVs SED YES L8ER GOT MEGA BILL 3 DONT GIV A SHIT BAILIFF DUE IN DAYS I O å£250 3 WANT å£800': 'spam',
#  'Good evening How are you': 'ham',
#  'What time you thinkin of goin': 'spam',
#  'Ya they are well and fine BBDpooja full pimpleseven she become quite blackand ur rite here its too cold wearing sweatter': 'spam',
#  'Congratulations ur awarded either a yrs supply of CDs from Virgin Records or a Mystery Gift GUARANTEED Call 09061104283 TsCs wwwsmsconet å£150pm approx 3mins': 'ham',
#  'Good afternoon loverboy How goes you day Any luck come your way I think of you sweetie and send my love across the sea to make you smile and happy': 'spam',
#  "Yetunde i'm sorry but moji and i seem too busy to be able to go shopping Can you just please find some other way to get what you wanted us to get Please forgive me You can reply free via yahoo messenger": 'spam',
#  'I will send them to your email Do you mind ltgt times per night': 'spam',
#  "I'm not coming home 4 dinner": 'spam',
#  "I call you later don't have network If urgnt sms me": 'spam',
#  'Hey check it da I have listed da': 'spam',
#  'Argh my 3g is spotty anyway the only thing I remember from the research we did was that province and sterling were the only problemfree places we looked at': 'spam',
#  'I will be gentle baby Soon you will be taking all ltgt inches deep inside your tight pussy': 'spam',
#  'Ill post her out l8r In class': 'ham',
#  'I dunno they close oredi not ÌÏ v ma fan': 'spam',
#  'By the way make sure u get train to worc foregate street not shrub hill Have fun night x': 'spam',
#  'Have a safe trip to Nigeria Wish you happiness and very soon company to share moments with': 'spam',
#  'Short But Cute \\Be a good person': 'spam',
#  "Hey Don't forget You are MINE For ME My possession MY property MMM childish smile ": 'spam',
#  'Eh u send wrongly lar': 'ham',
#  'from wwwApplausestorecom MonthlySubscription50pmsg max6month TCsC web age16 2stop txt stop': 'ham',
#  "Sorry man my stash ran dry last night and I can't pick up more until sunday": 'spam',
#  'Ku also dont msg or reply to his msg': 'ham',
#  'Tell where you reached': 'spam',
#  'SMS AUCTION A BRAND NEW Nokia 7250 is up 4 auction today Auction is FREE 2 join take part Txt NOKIA to 86021 now': 'ham',
#  'URGENT Your mobile number WON a å£2000 Bonus Caller prize on 100603 This is the 2nd attempt to reach you Call 09066368753 ASAP Box 97N7QP 150ppm': 'ham',
#  'I like to talk pa but am not able to I dont know y': 'ham',
#  'Sun cant come to earth but send luv as rays cloud cant come to river but send luv as rain I cant come to meet U but can send my care as msg to U Gud evng': 'spam',
#  'URGENT We are trying to contact you Last weekends draw shows that you have won a å£900 prize GUARANTEED Call 09061701939 Claim code S89 Valid 12hrs only': 'ham',
#  'Please CALL 08712402779 immediately as there is an urgent message waiting for you': 'ham',
#  'Your opinion about me 1 Over 2 Jada 3 Kusruthi 4 Lovable 5 Silent 6 Spl character 7 Not matured 8 Stylish 9 Simple Pls reply': 'spam',
#  "I'm really sorry I lit your hair on fire": 'spam',
#  'Take some small dose tablet for fever': 'spam',
#  'Hi did u decide wot 2 get 4 his bday if not ill prob jus get him a voucher frm virgin or sumfing ': 'spam',
#  'Hmmmhow many players selected': 'spam',
#  "Dizzamn aight I'll ask my suitemates when I get back": 'spam',
#  "Same here but I consider walls and bunkers and shit important just because I never play on peaceful but I guess your place is high enough that it don't matter": 'spam',
#  'Your next amazing xxx PICSFREE1 video will be sent to you enjoy If one vid is not enough for 2day text back the keyword PICSFREE1 to get the next video': 'ham',
#  'I not busy juz dun wan 2 go so early Hee ': 'spam',
#  'Ur HMV Quiz cashbalance is currently å£500 to maximize ur cashin now send HMV1 to 86688 only 150pmsg': 'ham',
#  "Hmm ok i'll stay for like an hour cos my eye is really sore": 'spam',
#  "ree entry in 2 a weekly comp for a chance to win an ipod Txt POD to 80182 to get entry std txt rate TC's apply 08452810073 for details 18": 'ham',
#  "I'm a guy browsin is compulsory": 'ham',
#  'ÌÏ go home liao Ask dad to pick me up at 6': 'spam',
#  "Love isn't a decision it's a feeling If we could decide who to love then life would be much simpler but then less magical": 'spam',
#  "She's good How are you Where r u working now": 'spam',
#  'Just normal only here ': 'spam',
#  'i felt sonot any conveying reason Ese he What about me': 'spam',
#  'I come n pick Ì up Come out immediately aft ur lesson': 'spam',
#  "Excellent I'll see what riley's plans are": 'spam',
#  'Oops 4 got that bit': 'spam',
#  "Yes They replied my mail I'm going to the management office later Plus will in to bank later alsoor on wednesday": 'spam',
#  'Whats that coming over the hill Is it a monster Hope you have a great day Things r going fine here busy though ': 'spam',
#  "It's justbeen overa week since we broke up and already our brains are going to mush": 'ham',
#  "I'm wif him now buying tix lar": 'spam',
#  'Ok Take ur time n enjoy ur dinner': 'spam',
#  'hi baby im cruisin with my girl friend what r u up 2 give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx': 'spam',
#  'I am thinking of going down to reg for pract lessons Flung my advance Haha wat time u going': 'spam',
#  'I feel like a dick because I keep sleeping through your texts and facebook messages Sup you in town': 'spam',
#  'Can you tell Shola to please go to college of medicine and visit the academic department tell the academic secretary what the current situation is and ask if she can transfer there She should ask someone to check Sagamu for the same thing and lautech Its vital she completes her medical education in Nigeria Its less expensive much less expensive Unless she will be getting citizen rates in new zealand': 'spam',
#  'Its ltgt k here oh Should i send home for sale': 'ham',
#  'I dunno until when Lets go learn pilates': 'spam',
#  "Are you sure you don't mean \\get here": 'spam',
#  'Painful words \\I thought being Happy was the most toughest thing on Earth But': 'spam',
#  'I think I‰Û÷m waiting for the same bus Inform me when you get there if you ever get there': 'spam',
#  'Dear Voucher Holder To claim this weeks offer at your PC please go to httpwwwwtlpcouktext TsCs apply': 'ham',
#  "This is hoping you enjoyed your game yesterday Sorry i've not been in touch but pls know that you are fondly bein thot off Have a great week Abiola": 'spam',
#  'Yo theres no class tmrw right': 'spam',
#  'Thanx 4 2day U r a goodmate I THINK UR RITE SARY ASUSUAL1 U CHEERED ME UP LOVE U FRANYxxxxx': 'spam',
#  'Gain the rights of a wifedont demand iti am trying as husband tooLets see': 'spam',
#  'Which channel': 'spam',
#  'Your account has been credited with 500 FREE Text Messages To activate just txt the word CREDIT to No 80488 TCs www80488biz': 'spam',
#  'Your brother is a genius': 'spam',
#  'First answer my question': 'spam',
#  'Get ur 1st RINGTONE FREE NOW Reply to this msg with TONE Gr8 TOP 20 tones to your phone every week just å£150 per wk 2 opt out send STOP 08452810071 16': 'ham',
#  'HELLO PEACH MY CAKE TASTS LUSH': 'spam',
#  'Congrats 1 year special cinema pass for 2 is yours call 09061209465 now C Suprman V Matrix3 StarWars3 etc all 4 FREE bx420ip45we 150pm Dont miss out': 'ham',
#  "Sure but since my parents will be working on Tuesday I don't really need a cover story": 'spam',
#  'Kkthis month kotees birthday know': 'spam',
#  'I have 2 sleeping bags 1 blanket and paper and phone details Anything else': 'spam',
#  'Hi here have birth at on the to at 8lb 7oz Mother and baby doing brilliantly': 'spam',
#  'Haha Sounds crazy dunno can tahan anot': 'spam',
#  "Anyway seriously hit me up when you're back because otherwise I have to light up with armand and he always has shit andor is vomiting": 'spam',
#  'No i am not having not any movies in my laptop': 'spam',
#  'Every mondaynxt week vl be completing': 'spam',
#  "No shit but I wasn't that surprised so I went and spent the evening with that french guy I met in town here and we fooled around a bit but I didn't let him fuck me": 'spam',
#  "No go No openings for that room 'til after thanksgiving without an upcharge": 'spam',
#  'Ok But bag again': 'ham',
#  'C movie is juz last minute decision mah Juz watch 2 lar but i tot Ì not interested': 'spam',
#  'We tried to contact you re our offer of New Video Phone 750 anytime any network mins HALF PRICE Rental camcorder call 08000930705 or reply for delivery Wed': 'ham',
#  'Like a personal sized or what': 'spam',
#  "Yes It's all innocent fun O": 'ham',
#  'Hey i booked the kb on sat already what other lessons are we going for ah Keep your sat night free we need to meet and confirm our lodging ': 'spam',
#  "K I'll be sure to get up before noon and see what's what": 'spam',
#  '<Forwarded from 21870000>Hi this is your Mailbox Messaging SMS alert You have 40 matches Please call back on 09056242159 to retrieve your messages and matches cc100pmin': 'ham',
#  'Aiyo cos i sms Ì then Ì neva reply so i wait 4 Ì to reply lar I tot Ì havent finish ur lab wat': 'spam',
#  'He neva grumble but i sad lor Hee Buy tmr lor aft lunch But we still meetin 4 lunch tmr a not Neva hear fr them lei ÌÏ got a lot of work ar': 'spam',
#  'It just seems like weird timing that the night that all you and g want is for me to come smoke is the same day as when a shitstorm is attributed to me always coming over and making everyone smoke': 'spam',
#  'Ladies first and genus second k ': 'spam',
#  'If you are not coughing then its nothing': 'ham',
#  'Ok i wont call or disturb any one I know all are avoiding me I am a burden for all': 'spam',
#  'Can i meet Ì at 5 As 4 where depends on where Ì wan 2 in lor': 'spam',
#  "Hi i won't b ard 4 christmas But do enjoy n merry x'mas": 'ham',
#  'Think i might have to give it a miss Am teaching til twelve then have lecture at two Damn this working thing': 'spam',
#  " said kiss kiss i can't do the sound effects He is a gorgeous man isn't he Kind of person who needs a smile to brighten his day ": 'spam',
#  'Just glad to be talking to you': 'spam',
#  'I am in escape theatre now Going to watch KAVALAN in a few minutes': 'spam',
#  'Me fineabsolutly fine': 'spam',
#  'How dare you change my ring': 'spam',
#  'He is a womdarfull actor': 'ham',
#  'I wait 4 Ì inside da car park': 'spam',
#  'A boy was late 2 home His father \\POWER OF FRNDSHIP\\': 'spam',
#  'Si will take mokka players only': 'spam',
#  'Oh god i am happy to see your message after 3 days': 'ham',
#  "Plz note if anyone calling from a mobile Co amp asks u to type ltgt or ltgt Do not do so Disconnect the callcoz it iz an attempt of 'terrorist' to make use of the sim card no Itz confirmd by nokia n motorola n has been verified by CNN IBN": 'spam',
#  'Customer Loyalty OfferThe NEW Nokia6650 Mobile from ONLY å£10 at TXTAUCTION Txt word START to No 81151 get yours Now 4TCtxt TC 150pMTmsg': 'ham',
#  'Sounds like something that someone testing me would sayy': 'spam',
#  "Was just about to ask Will keep this one Maybe that's why you didn't get all the messages we sent you on glo": 'spam',
#  'Where did u go My phone is gonna die you have to stay in here': 'ham',
#  'I know you are thinkin malaria But relax children cant handle malaria She would have been worse and its gastroenteritis If she takes enough to replace her loss her temp will reduce And if you give her malaria meds now she will just vomit Its a self limiting illness she has which means in a few days it will completely stop': 'spam',
#  'I sent them Do you like': 'ham',
#  "Hmmmy uncle just informed me that he's paying the school directly So pls buy food": 'spam',
#  "You are always putting your business out there You put pictures of your ass on facebook You are one of the most open people i've ever met Why would i think a picture of your room would hurt you make you feel violated": 'spam',
#  "How would my ip address test that considering my computer isn't a minecraft server": 'spam',
#  'Really do hope the work doesnt get stressful Have a gr8 day': 'spam',
#  'If i let you do this i want you in the house by 8am': 'ham',
#  'Rajipls do me a favour Pls convey my Birthday wishes to Nimya Pls Today is her birthday': 'spam',
#  'wiskey Brandy Rum Gin Beer Vodka Scotch Shampain Wine \\KUDI\\yarasu dhina vaazhthukkal ': 'spam',
#  'Hello No news on job they are making me wait a fifth week Yeah im up for some woozles and weasels In exeter still but be home about 3 ': 'ham',
#  'ÌÏ only send me the contents page': 'spam',
#  'Someone has contacted our dating service and entered your phone because they fancy you To find out who it is call from a landline 09111032124 PoBox12n146tf150p': 'ham',
#  'YES The only place in town to meet exciting adult singles is now in the UK Txt CHAT to 86688 now 150pMsg': 'ham',
#  'Very hurting n meaningful lines ever \\I compromised everything for my love': 'spam',
#  'Wat time u finish ur lect today': 'spam',
#  "Storming msg Wen u lift d phne u say \\HELLO\\ Do u knw wt is d real meaning of HELLO  It's d name of a girl  Yes And u knw who is dat girl \\Margaret Hello\\ She is d girlfrnd f Grahmbell who invnted telphone   MoralOne can 4get d name of a person": 'spam',
#  'At WHAT TIME should i come tomorrow': 'spam',
#  'Hi dude hw r u da realy mising u today': 'spam',
#  "How did you find out in a way that didn't include all of these details": 'ham',
#  'Cos daddy arranging time c wat time fetch Ì mah': 'spam',
#  'Let there be snow Let there be snow This kind of weather brings ppl together so friendships can grow': 'spam',
#  'You getting back any time soon': 'ham',
#  'Or ill be a little closer like at the bus stop on the same street': 'spam',
#  "Haven't heard anything and he's not answering my texts so I'm guessing he flaked That said the jb is fantastic": 'spam',
#  'Lets use it next week princess ': 'spam',
#  'No I was trying it all weekend V': 'ham',
#  ...}

# %%
# Lista com apenas spam's e ham's
results = []
for i in dados_teste:
    results.append(tudo_certo[i])

# %%
df_meus = pd.DataFrame({
    'Class' : results,
    'Emails' : dados_teste
})

# %%
valores_reais = dados_reais.Class.values

# %%
df_comp = pd.DataFrame({
    'Minhas' : results,
    'Reais' : valores_reais
})

# %%
# % de acertos
spam_spam = df_comp.Minhas[(df_comp.Minhas == 'spam') & (df_comp.Reais == 'spam')].count()
spam_ham = df_comp.Minhas[(df_comp.Minhas == 'spam') & (df_comp.Reais == 'ham')].count()
ham_ham = df_comp.Minhas[(df_comp.Minhas == 'ham') & (df_comp.Reais == 'ham')].count()
ham_spam = df_comp.Minhas[(df_comp.Minhas == 'ham') & (df_comp.Reais == 'spam')].count()

# %%
print(pd.crosstab(df_comp.Reais,df_comp.Minhas))
# Out:
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20

# %% [markdown]
# # Testando o Classificador

# %%
def reclass(dados_teste,spam_dic,ham_dic,Pspam,Pham,roc):
    tudo_certo = classificando(dados_teste,spam_dic,ham_dic,Pspam,Pham,roc)
    results = []
    for i in dados_teste:
        results.append(tudo_certo[i])
    df_meus = pd.DataFrame({
        'Class' : results,
        'Emails' : dados_teste
    })
    valores_reais = dados_reais.Class.values
    df_comp = pd.DataFrame({
        'Minhas' : results,
        'Reais' : valores_reais
    })
    spam_spam = df_comp.Minhas[(df_comp.Minhas == 'spam') & (df_comp.Reais == 'spam')].count()
    spam_ham = df_comp.Minhas[(df_comp.Minhas == 'spam') & (df_comp.Reais == 'ham')].count()
    ham_ham = df_comp.Minhas[(df_comp.Minhas == 'ham') & (df_comp.Reais == 'ham')].count()
    ham_spam = df_comp.Minhas[(df_comp.Minhas == 'ham') & (df_comp.Reais == 'spam')].count()

    return df_comp, spam_spam, spam_ham, ham_ham, ham_spam

# %%
r = np.arange(0,1,0.001)
sensibilidade = []
especificidade = []
lista_SV = []
lista_SF = []
lista_HV = []
lista_HF = []

for roca in r:
    df_comp, spam_spam, spam_ham, ham_ham, ham_spam = reclass(dados_teste,spam_dic,ham_dic,Pspam,Pham,roca)
    curva_intel_verdadeiro = spam_spam/(spam_spam + spam_ham)
    curva_intel_falso = ham_ham/(ham_ham + ham_spam)
    sensibilidade.append(curva_intel_verdadeiro)
    especificidade.append(curva_intel_falso)
    lista_SV.append(spam_spam)
    lista_SF.append(spam_ham)
    lista_HV.append(ham_ham)
    lista_HF.append(ham_spam)
    print(pd.crosstab(df_comp.Reais,df_comp.Minhas))
    print('\n')
# Out:
# Minhas  spam
# Reais
# ham     1209
# spam     184
#
#
# Minhas  ham  spam
# Reais
# ham      33  1176
# spam    153    31
#
#
# Minhas  ham  spam
# Reais
# ham      42  1167
# spam    154    30
#
#
# Minhas  ham  spam
# Reais
# ham      51  1158
# spam    155    29
#
#
# Minhas  ham  spam
# Reais
# ham      58  1151
# spam    156    28
#
#
# Minhas  ham  spam
# Reais
# ham      59  1150
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      63  1146
# spam    157    27
# C:\Users\Ester Quintino\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in long_scalars
#   if sys.path[0] == '':
# Minhas  ham  spam
# Reais
# ham      70  1139
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      71  1138
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      75  1134
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      79  1130
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      79  1130
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      79  1130
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      84  1125
# spam    157    27
#
#
# Minhas  ham  spam
# Reais
# ham      85  1124
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      86  1123
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      87  1122
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      89  1120
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      92  1117
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      94  1115
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      94  1115
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      94  1115
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      95  1114
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      96  1113
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      97  1112
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      97  1112
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      98  1111
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      99  1110
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham      99  1110
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     100  1109
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     101  1108
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     102  1107
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     102  1107
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     103  1106
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     103  1106
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     103  1106
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     104  1105
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     104  1105
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     104  1105
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     106  1103
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     106  1103
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     108  1101
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     108  1101
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     109  1100
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     109  1100
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     110  1099
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     110  1099
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     111  1098
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     111  1098
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     114  1095
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     114  1095
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     115  1094
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     115  1094
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     116  1093
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     116  1093
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     116  1093
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     116  1093
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     116  1093
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     116  1093
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     117  1092
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     117  1092
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     117  1092
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     117  1092
# spam    158    26
#
#
# Minhas  ham  spam
# Reais
# ham     119  1090
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     119  1090
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     119  1090
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     119  1090
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     120  1089
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     121  1088
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     121  1088
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     121  1088
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     121  1088
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     122  1087
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     122  1087
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     122  1087
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     123  1086
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     123  1086
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     124  1085
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     124  1085
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     125  1084
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     125  1084
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     126  1083
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     126  1083
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     126  1083
# spam    159    25
#
#
# Minhas  ham  spam
# Reais
# ham     127  1082
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     128  1081
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     129  1080
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     130  1079
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     131  1078
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     132  1077
# spam    160    24
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     167  1042
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    161    23
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     168  1041
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     169  1040
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     169  1040
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     169  1040
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     169  1040
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     169  1040
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     170  1039
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     170  1039
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     172  1037
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     172  1037
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     173  1036
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     173  1036
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     174  1035
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     175  1034
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     176  1033
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     176  1033
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     177  1032
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     178  1031
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     179  1030
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     180  1029
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     180  1029
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     180  1029
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     180  1029
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     181  1028
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     181  1028
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     181  1028
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     181  1028
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     182  1027
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    162    22
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     183  1026
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     184  1025
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     185  1024
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     185  1024
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     185  1024
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     185  1024
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     185  1024
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     186  1023
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     187  1022
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    163    21
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     188  1021
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     189  1020
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     190  1019
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     190  1019
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     190  1019
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     191  1018
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     192  1017
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     193  1016
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     194  1015
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     195  1014
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     196  1013
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     197  1012
# spam    164    20
#
#
# Minhas  ham  spam
# Reais
# ham     197  1012
# ...
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     214   995
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     214   995
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     214   995
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     215   994
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     216   993
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     216   993
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     217   992
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     217   992
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     217   992
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     218   991
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     219   990
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     220   989
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     221   988
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     221   988
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     221   988
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     221   988
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     221   988
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    166    18
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     222   987
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     223   986
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     223   986
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     223   986
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     223   986
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     223   986
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     223   986
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     224   985
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     225   984
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     225   984
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     225   984
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     225   984
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     226   983
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     226   983
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     226   983
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     227   982
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     227   982
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     227   982
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     230   979
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     230   979
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     231   978
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     233   976
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     233   976
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     235   974
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     235   974
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     235   974
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     235   974
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     235   974
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     236   973
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     236   973
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     237   972
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     237   972
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     237   972
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     238   971
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     240   969
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     240   969
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     240   969
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     241   968
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     242   967
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     242   967
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     242   967
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     242   967
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     242   967
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     243   966
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     243   966
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     243   966
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     243   966
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     243   966
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     244   965
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     244   965
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     244   965
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     244   965
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     244   965
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     244   965
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     245   964
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     246   963
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     246   963
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     246   963
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     246   963
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     247   962
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     248   961
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     249   960
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     249   960
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     249   960
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     249   960
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     249   960
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     249   960
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     250   959
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     250   959
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     250   959
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     251   958
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     252   957
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     252   957
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     252   957
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     252   957
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     253   956
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     253   956
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     254   955
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     256   953
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     257   952
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     258   951
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     259   950
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     259   950
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     260   949
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     260   949
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     261   948
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     261   948
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     264   945
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     264   945
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     266   943
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     267   942
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     267   942
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     268   941
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     268   941
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     269   940
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     269   940
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     270   939
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     270   939
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     271   938
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     273   936
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     273   936
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     274   935
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     277   932
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     277   932
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     277   932
# spam    167    17
#
#
# Minhas  ham  spam
# Reais
# ham     278   931
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     279   930
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     283   926
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     286   923
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     292   917
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     295   914
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     295   914
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     296   913
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     298   911
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     299   910
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     303   906
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     307   902
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     309   900
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     310   899
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     311   898
# spam    169    15
#
#
# Minhas  ham  spam
# Reais
# ham     319   890
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     321   888
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     324   885
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     328   881
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     332   877
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     337   872
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     346   863
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     359   850
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     371   838
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     386   823
# spam    170    14
#
#
# Minhas  ham  spam
# Reais
# ham     409   800
# spam    171    13

# %%
sensibilidade = sorted(sensibilidade)
especificidade = sorted(especificidade)

# %%
jeca.plot(sensibilidade,especificidade)
jeca.show()

# %% [markdown]
# ##### Printando o teste com os dados reais
# for i in range(len(dados_reais)):
#     print(str(dados_reais.Class[i:i+1].values) + ',' + str(df.Class[i:i+1].values))
#     if dados_reais.Class[i:i+1].values == df.Class[i:i+1].values:
#         print('True')
#     elif dados_reais.Class[i:i+1].values != df.Class[i:i+1].values:
#         print('False'

# %% [markdown]
# ## 4. Curva ROC

# %% [markdown]
# ___
# ## 5. Qualidade do Classificador alterando a base de treinamento
